# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %%
path_bispec='/home/nessa/Documents/Projects/LensingBispectrum/CMB-nonlinear/outputs/bispectra/'
path_powspec='/home/nessa/Documents/Projects/LensingBispectrum/CMB-nonlinear/outputs/power_spectra/'

# %%
ll,clppzs1,zmaxs=pickle.load(open(path_powspec+'cl_pp_zbins_Pratten_Paper_nlzs1.pkl','r'))
clppzs1=clppzs1[0]
ll,clpp,zmaxs=pickle.load(open(path_powspec+'cl_pp_zbins_Pratten_Paper_nlzcmb.pkl','r'))
print(zmaxs)
clppcmb = clpp[1]
clppz1 = clpp[0]
# Out:
# [1.0, 1089.3979798318112]

# %%
plt.figure()
plt.semilogx(ll,ll**4*clppz1, label='zmax=1')
plt.semilogx(ll,ll**4*clppcmb, label='classic')
plt.semilogx(ll,ll**4*clppzs1, label='zsource=1')
plt.legend()
plt.show()

plt.figure()
plt.semilogx(ll,clppz1/clppcmb, label='zmax=1')
plt.semilogx(ll,clppzs1/clppcmb, label='zsource=1')
plt.legend()
plt.show()

# %%
ell_file='/home/nessa/Documents/Projects/LensingBispectrum/CMB-nonlinear/outputs/ells/'+'ell_ang_folded_Lmin1_Lmax10000_lmin1_lmax10000_lenL200_lenl220_lenang200_1e-04.pkl'
L,l,theta=pickle.load(open(ell_file, 'r'))
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-11-f8aecc1485fe> in <module>()
#       1 ell_file='/home/nessa/Documents/Projects/LensingBispectrum/CMB-nonlinear/outputs/ells/'+'ell_ang_folded_Lmin1_Lmax10000_lmin1_lmax10000_lenL200_lenl220_lenang200_1e-04.pkl'
# ----> 2 L,l,theta=pickle.load(open(ell_file+'_post_born.npy', 'r'))
#       3
#
# IOError: [Errno 2] No such file or directory: '/home/nessa/Documents/Projects/LensingBispectrum/CMB-nonlinear/outputs/ells/ell_ang_folded_Lmin1_Lmax10000_lmin1_lmax10000_lenL200_lenl220_lenang200_1e-04.pkl_post_born.npy'

# %%
#zcmb

filename1=path_bispec+'bispec_phi_kkk_foldedanalytic_red_dis_lnPs_Bfit_Pratten_Paperzcmb_Lmin1-Lmax10000-lmax5000-lenBi250_GM'
filename2=path_bispec+'bispec_phi_kkk_foldedanalytic_red_dis_lnPs_Bfit_Pratten_Paperzcmb_Lmin1-Lmax10000-lmax5000-lenBi250_GM_post_born'
filename3=path_bispec+'bispec_phi_kkk_foldedanalytic_red_dis_lnPs_Bfit_Pratten_Paperzcmb_Lmin1-Lmax10000-lmax5000-lenBi250_GM_post_born_sum'
bi_phi_LSS=np.load(filename1+'.npy')
bi_phi_pB=np.load(filename2+'.npy')
bi_phi_sum=np.load(filename3+'.npy')

#CLASS Cls

plt.style.use('classic')
colors=['black', 'm','y','blue','black']
plt.figure()
plt.loglog(L,L*bi_phi_LSS1)
plt.loglog(L,-L*bi_phi_pB, ls='--')
plt.loglog(L,L*bi_phi_sum, ls=':')
plt.loglog(L,-L*bi_phi_sum, ls=':')
plt.grid()
plt.xlim(10,10000)
#plt.ylim(1e-3,1e1)
plt.tick_params(labelright=True)
#plt.savefig('./validation_plots/equilat_zcmb_overcl_SCfit.pdf')
plt.show()

plt.figure()
plt.semilogx(L,bi_phi_pB/bi_phi_sum)
plt.grid()
plt.xlim(10,10000)
plt.ylim(-1.,1)
plt.tick_params(labelright=True)
#plt.savefig('./validation_plots/equilat_zcmb_overcl_SCfit.pdf')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-192698b1a887> in <module>()
#      13 colors=['black', 'm','y','blue','black']
#      14 plt.figure()
# ---> 15 plt.loglog(L,L*bi_phi_LSS1)
#      16 plt.loglog(L,-L*bi_phi_pB, ls='--')
#      17 plt.loglog(L,L*bi_phi_sum, ls=':')
#
# NameError: name 'bi_phi_LSS1' is not defined

# %%
#zcmbzmax1

filename1=path_bispec+'bispec_phi_kkk_foldedanalytic_red_dis_lnPs_Bfit_Pratten_Paperzmax1_Lmin1-Lmax10000-lmax5000-lenBi250_GM'
filename2=path_bispec+'bispec_phi_kkk_foldedanalytic_red_dis_lnPs_Bfit_Pratten_Paperzmax1_Lmin1-Lmax10000-lmax5000-lenBi250_GM_post_born'
filename3=path_bispec+'bispec_phi_kkk_foldedanalytic_red_dis_lnPs_Bfit_Pratten_Paperzmax1_Lmin1-Lmax10000-lmax5000-lenBi250_GM_post_born_sum'
bi_phi_LSS1=np.load(filename1+'.npy')
bi_phi_pB1=np.load(filename2+'.npy')
bi_phi_sum1=np.load(filename3+'.npy')

#CLASS Cls

plt.style.use('classic')
colors=['black', 'm','y','blue','black']
plt.figure()
plt.loglog(L,L*bi_phi_LSS1)
plt.loglog(L,-L*bi_phi_pB1, ls='--')
plt.loglog(L,L*bi_phi_sum1, ls=':')
plt.loglog(L,-L*bi_phi_sum1, ls=':')
plt.grid()
plt.xlim(10,10000)
#plt.ylim(1e-3,1e1)
plt.tick_params(labelright=True)
#plt.savefig('./validation_plots/equilat_zcmb_overcl_SCfit.pdf')
plt.show()

plt.figure()
plt.semilogx(L,bi_phi_pB1/bi_phi_sum1)
plt.grid()
plt.xlim(10,10000)
#plt.ylim(1e-3,1e1)
plt.tick_params(labelright=True)
#plt.savefig('./validation_plots/equilat_zcmb_overcl_SCfit.pdf')
plt.show()

# %%
#zcmbzmax1

filename1=path_bispec+'bispec_phi_kkk_foldedanalytic_red_dis_lnPs_Bfit_Pratten_Paperzmax1wrong_Lmin1-Lmax10000-lmax5000-lenBi250_GM'
filename2=path_bispec+'bispec_phi_kkk_foldedanalytic_red_dis_lnPs_Bfit_Pratten_Paperzmax1wrong_Lmin1-Lmax10000-lmax5000-lenBi250_GM_post_born'
filename3=path_bispec+'bispec_phi_kkk_foldedanalytic_red_dis_lnPs_Bfit_Pratten_Paperzmax1wrong_Lmin1-Lmax10000-lmax5000-lenBi250_GM_post_born_sum'
bi_phi_LSS1w=np.load(filename1+'.npy')
bi_phi_pB1w=np.load(filename2+'.npy')
bi_phi_sum1w=np.load(filename3+'.npy')

#CLASS Cls

plt.style.use('classic')
colors=['black', 'm','y','blue','black']
plt.figure()
plt.loglog(L,L*bi_phi_LSS1)
plt.loglog(L,-L*bi_phi_pB1w, ls='--')
plt.loglog(L,L*bi_phi_sum1w, ls=':')
plt.loglog(L,-L*bi_phi_sum1w, ls=':')
plt.loglog(L,L*bi_phi_sum1, ls='-')
plt.loglog(L,-L*bi_phi_sum1, ls='-')
plt.grid()
plt.xlim(10,10000)
#plt.ylim(1e-3,1e1)
plt.tick_params(labelright=True)
#plt.savefig('./validation_plots/equilat_zcmb_overcl_SCfit.pdf')
plt.show()

plt.figure()
plt.semilogx(L,bi_phi_sum1w/bi_phi_sum1)
plt.grid()
plt.xlim(10,10000)
#plt.ylim(1e-3,1e1)
plt.tick_params(labelright=True)
#plt.savefig('./validation_plots/equilat_zcmb_overcl_SCfit.pdf')
plt.show()

# %%
#zsource1

filename1=path_bispec+'bispec_phi_kkk_foldedanalytic_red_dis_lnPs_Bfit_Pratten_Paperzs1_Lmin1-Lmax10000-lmax5000-lenBi250_GM'
filename2=path_bispec+'bispec_phi_kkk_foldedanalytic_red_dis_lnPs_Bfit_Pratten_Paperzs1_Lmin1-Lmax10000-lmax5000-lenBi250_GM_post_born'
filename3=path_bispec+'bispec_phi_kkk_foldedanalytic_red_dis_lnPs_Bfit_Pratten_Paperzs1_Lmin1-Lmax10000-lmax5000-lenBi250_GM_post_born_sum'
bi_phi_LSSs=np.load(filename1+'.npy')
bi_phi_pBs=np.load(filename2+'.npy')
bi_phi_sums=np.load(filename3+'.npy')

#CLASS Cls

plt.style.use('classic')
colors=['black', 'm','y','blue','black']
plt.figure()
plt.loglog(L,L*bi_phi_LSSs)
plt.loglog(L,-L*bi_phi_pBs, ls='--')
plt.loglog(L,L*bi_phi_sums, ls=':')
plt.loglog(L,-L*bi_phi_sums, ls=':')
plt.grid()
plt.xlim(10,10000)
#plt.ylim(1e-3,1e1)
plt.tick_params(labelright=True)
#plt.savefig('./validation_plots/equilat_zcmb_overcl_SCfit.pdf')
plt.show()

plt.figure()
plt.semilogx(L,bi_phi_pBs/bi_phi_sums)
plt.grid()
plt.xlim(10,10000)
#plt.ylim(1e-3,1e1)
plt.tick_params(labelright=True)
#plt.savefig('./validation_plots/equilat_zcmb_overcl_SCfit.pdf')
plt.show()


#seems much bigger in comparison to original, > factor 2
plt.figure()
plt.semilogx(L,bi_phi_sum1/abs(bi_phi_sum))
plt.grid()
plt.xlim(10,10000)
plt.ylim(-1,20)
plt.tick_params(labelright=True)
#plt.savefig('./validation_plots/equilat_zcmb_overcl_SCfit.pdf')
plt.show()

#smaller in comparison to original
plt.figure()
plt.semilogx(L,bi_phi_sums/abs(bi_phi_sum))
plt.grid()
plt.xlim(10,10000)
plt.ylim(-1,3)
plt.tick_params(labelright=True)
#plt.savefig('./validation_plots/equilat_zcmb_overcl_SCfit.pdf')
plt.show()

# %%
#seems much bigger in comparison to original, > factor 2
plt.figure()
plt.loglog(L,bi_phi_sum1)
plt.loglog(L,bi_phi_sum)
plt.loglog(L,-bi_phi_sum)
plt.grid()
plt.xlim(10,10000)
plt.tick_params(labelright=True)
#plt.savefig('./validation_plots/equilat_zcmb_overcl_SCfit.pdf')
plt.show()
