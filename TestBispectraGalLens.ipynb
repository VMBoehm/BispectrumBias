# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pickle
import numpy as np
plt.style.use(['seaborn-colorblind','paper'])
plt.style.use('classic')

# %%
ellpath="/home/nessa/Documents/Projects/LensingBispectrum/CMB-nonlinear/outputs/ells/"
specpath='/home/nessa/Documents/Projects/LensingBispectrum/CMB-nonlinear/outputs/bispectra/'

# %%
#folded
L,l,theta = pickle.load(open(ellpath+'ell_ang_folded_Lmin10_Lmax10000_lmin10_lmax8000_lenL200_lenl220_lenang200_0e+00.pkl','r'))
bi_fold_tl = np.load(specpath+'bispec_phi_test_folded_Pratten_Paper_Lmin10-Lmax10000-lmax5000-lenBi200_.npy')
bi_fold_fit = np.load(specpath+'bispec_phi_test_folded_Pratten_Paper_Lmin10-Lmax10000-lmax5000-lenBi200_SC.npy')

plt.figure()

plt.loglog(L, bi_fold_tl)
plt.loglog(L, bi_fold_fit)
plt.xlim(100,10000)
plt.ylim(1e-20,1e-13)
plt.show()

# %%
#equilat
L,l,theta = pickle.load(open(ellpath+'ell_ang_equilat_Lmin10_Lmax10000_lmin10_lmax8000_lenL200_lenl220_lenang200_0e+00.pkl','r'))
bi_equi_tl = np.load(specpath+'bispec_phi_test_equilat_Pratten_Paper_Lmin10-Lmax10000-lmax10000-lenBi200_.npy')
bi_equi_fit = np.load(specpath+'bispec_phi_test_equilat_Pratten_Paper_Lmin10-Lmax10000-lmax10000-lenBi200_SC.npy')

plt.figure()

plt.loglog(L, bi_equi_tl)
plt.loglog(L, bi_equi_fit)
plt.xlim(100,10000)
plt.ylim(1e-20,1e-13)
plt.show()

# %%
specpath='/home/nessa/Documents/Projects/LensingBispectrum/CMB-nonlinear/outputs/bispectra/'
L,l,theta = pickle.load(open(ellpath+'ell_ang_equilat_Lmin10_Lmax3000_lmin10_lmax8000_lenL200_lenl220_lenang200_0e+00.pkl','r'))
bi_equi_111t = np.load(specpath+'bispec_TakadaRetest2_equilat_Takada_Lmin10-Lmax2999-lmax2999_halofit_SC.npy')
bi_equi_111 = np.load(specpath+'bispec_111_equilat_Takada_Lmin10-Lmax2999-lmax2999_halofit_SC.npy')
bi_equi_222 = np.load(specpath+'bispec_222_equilat_Takada_Lmin10-Lmax2999-lmax2999_halofit_SC.npy')
bi_equi_112 = np.load(specpath+'bispec_112_equilat_Takada_Lmin10-Lmax2999-lmax2999_halofit_SC.npy')
bi_equi_122 = np.load(specpath+'bispec_122_equilat_Takada_Lmin10-Lmax2999-lmax2999_halofit_SC.npy')
plt.figure()
plt.title('Fig. 3 in astro-ph/0310125v4' )
plt.loglog(L, L**4*bi_equi_111/(2*np.pi)**2,c='r',label='111')
plt.loglog(L, L**4*bi_equi_111t/(2*np.pi)**2,c='k',ls='--',label='111 retest')
plt.loglog(L, L**4*bi_equi_222/(2*np.pi)**2,c='b',label='222')
plt.loglog(L, L**4*bi_equi_112/(2*np.pi)**2,c='g',label='112')
plt.loglog(L, L**4*bi_equi_122/(2*np.pi)**2,c='orange',label='122')
plt.xlim(10,3000)
plt.ylim(5e-11,3e-5)
plt.legend(loc='best')
plt.xlabel('L')
plt.ylabel('$L^4 B(L,L,L)/(2\pi)^2$')
plotpath='/home/nessa/Documents/Projects/LensingBispectrum/CMB-nonlinear/Tests/GalaxyLensing/'
plt.savefig(plotpath+'bispec_equilat.png',bbox_inches='tight')
plt.show()

# %%
L,l,theta   = pickle.load(open(ellpath+'ell_ang_equilat_Lmin10_Lmax3000_lmin10_lmax8000_lenL200_lenl220_lenang200_0e+00.pkl','r'))
specpath='/home/nessa/Documents/Projects/LensingBispectrum/CMB-nonlinear/outputs/power_spectra/'
CL_11 = np.load(specpath+'CL_111_equilat_Takada_Lmin10-Lmax2999_halofit.npy')
CL_11t = np.load(specpath+'CL_TakadaRetest2_equilat_Takada_Lmin10-Lmax2999_halofit.npy')
CL_22 = np.load(specpath+'CL_222_equilat_Takada_Lmin10-Lmax2999_halofit.npy')
CL_12 = np.load(specpath+'CL_122_equilat_Takada_Lmin10-Lmax2999_halofit.npy')
plt.figure()
plt.title('Fig. 2 in astro-ph/0310125v4' )
plt.loglog(L, L*(L+1)*CL_11/(2*np.pi),c='r',label='11')
plt.loglog(L, L*(L+1)*CL_11t/(2*np.pi),c='k',ls='--',label='11 retest')
plt.loglog(L, L*(L+1)*CL_22/(2*np.pi),c='b',label='22')
plt.loglog(L, L*(L+1)*CL_12/(2*np.pi),c='g',label='12')
plt.xlim(10,3000)
plt.ylim(1e-6,1e-3)
plt.ylabel('$L(L+1) C_L^{\kappa \kappa}/(2\pi)$')
plt.xlabel('L')
plt.legend(loc='best')
plotpath='/home/nessa/Documents/Projects/LensingBispectrum/CMB-nonlinear/Tests/GalaxyLensing/'
plt.savefig(plotpath+'CLs.png',bbox_inches='tight')
plt.show()

# %%
specpath='/home/nessa/Documents/Projects/LensingBispectrum/CMB-nonlinear/outputs/bispectra/'
L,l,theta = pickle.load(open(ellpath+'ell_ang_equilat_Lmin10_Lmax3000_lmin10_lmax8000_lenL200_lenl220_lenang200_0e+00.pkl','r'))
bi_equi = np.load(specpath+'bispec_111_equilat_JiaGalaxyLens_Lmin10-Lmax2999-lmax2999__.npy')
bi_equinl = np.load(specpath+'bispec_111_equilat_JiaGalaxyLens_Lmin10-Lmax2999-lmax2999_halofit_.npy')
bi_equifit = np.load(specpath+'bispec_111_equilat_JiaGalaxyLens_Lmin10-Lmax2999-lmax2999_halofit_SC.npy')
#bi_equitest = np.load(specpath+'bispec_111test_equilat_JiaGalaxyLens_Lmin10-Lmax2999-lmax2999_halofit.npy')
bi_equi333 = np.load(specpath+'bispec_333_equilat_JiaGalaxyLens_Lmin10-Lmax2999-lmax2999_halofit_SC.npy')
bi_equi333nu = np.load(specpath+'bispec_333_massive_nus_equilat_JiaGalaxyLens_Lmin10-Lmax2999-lmax2999_halofit_.npy')
bi_equi111nu = np.load(specpath+'bispec_111_massive_nus_equilat_JiaGalaxyLens_Lmin10-Lmax2999-lmax2999_halofit_.npy')
bi_equi333sq = np.load(specpath+'bispec_333_squeezed_ang0.0001_JiaGalaxyLens_Lmin10-Lmax2999-lmax2999_halofit_.npy')
bi_equi333sq2 = np.load(specpath+'bispec_333_squeezed_ang0.001_JiaGalaxyLens_Lmin10-Lmax2999-lmax2999_halofit_.npy')
plt.figure()
plt.loglog(L, L**2*bi_equifit,label='111 SC fit')
#plt.loglog(L, L**2*bi_equi111nu,label='111 SC fit nu=0.1')
#plt.loglog(L, L**2*bi_equi333nu,label='333 SC fit nu=0.1')
# plt.loglog(L, L**2*bi_equi333sq,label='333 TL nl ang 1 squeezed')
# plt.loglog(L, L**2*bi_equi333sq,label='333 TL nl ang 2 squeezed',ls='--')
# plt.loglog(L, L**2*bi_equinl,label='111 TL non linear')
#plt.loglog(L, L**2*bi_equi,label='111 SC fit')
plt.loglog(L, L**2*bi_equi333,c='r',ls ='--',label='333 SC fit')
#plt.loglog(L, L**2*bi_equi333fold,c='r',ls ='-.',label='333 SC fit folded')
plt.xlim(100,3000)
plt.legend(loc='best')
plt.xlabel('L')
plt.ylabel('$L^2 b(L,L,L)$')
plotpath='/home/nessa/Documents/Projects/LensingBispectrum/CMB-nonlinear/Tests/GalaxyLensing/'
plt.savefig(plotpath+'bispec_equilat_nus.png',bbox_inches='tight')
plt.show()

# %%
L,l,theta   = pickle.load(open(ellpath+'ell_ang_equilat_Lmin10_Lmax3000_lmin10_lmax8000_lenL200_lenl220_lenang200_0e+00.pkl','r'))
specpath='/home/nessa/Documents/Projects/LensingBispectrum/CMB-nonlinear/outputs/power_spectra/'
CL_11 = np.load(specpath+'CL_111_equilat_JiaGalaxyLens_Lmin10-Lmax2999_.npy')
CL_11nu = np.load(specpath+'CL_111_massive_nus_equilat_JiaGalaxyLens_Lmin10-Lmax2999_halofit.npy')
CL_11nl = np.load(specpath+'CL_111_equilat_JiaGalaxyLens_Lmin10-Lmax2999_halofit.npy')
ll, cls11, cls11_ = np.load(specpath+'CL_111_equilat_JiaGalaxyLens_Lmin10-Lmax2999_halofit_CLASS.npy')
CL_33nl = np.load(specpath+'CL_333_equilat_JiaGalaxyLens_Lmin10-Lmax2999_halofit.npy')
ll, cls33, cls33_ = np.load(specpath+'CL_333_folded_JiaGalaxyLens_Lmin10-Lmax2999_halofit_CLASS.npy')
CL_33nu = np.load(specpath+'CL_333_massive_nus_equilat_JiaGalaxyLens_Lmin10-Lmax2999_halofit.npy')

L_,l_,theta   = pickle.load(open(ellpath+'ell_ang_equilat_Lmin10_Lmax10000_lmin10_lmax8000_lenL200_lenl220_lenang200_0e+00.pkl','r'))
CL_11t = np.load(specpath+'CL_111_retest_equilat_JiaGalaxyLens_Lmin10-Lmax10000_halofit.npy')
CL_33t = np.load(specpath+'CL_333_retest_equilat_JiaGalaxyLens_Lmin10-Lmax10000_halofit.npy')
CL_33nut = np.load(specpath+'CL_333_massive_nus_equilat_JiaGalaxyLens_Lmin10-Lmax10000_halofit.npy')


plt.figure()
plt.title('Lensing Power Spectra' )
plt.loglog(L,CL_11nu,label='11 nl mnu=0.1')
plt.loglog(L,CL_11nl,label='11 nl')

#plt.loglog(ll1,cls11_,ls='--',label='CLASS 11 nl')
plt.loglog(L,CL_33nl,label='33 nl')
plt.loglog(L,CL_33nu,label='33 nl mnu=0.1')
plt.loglog(L_,CL_11t,label='11 retest', ls='-.')
plt.loglog(L_,CL_33t,label='33 retest', ls='-.')
plt.loglog(L_,CL_33nut,label='33 mnu=0.1 retest', ls='-.')

#plt.loglog(ll,cls33_,ls='--',label='CLASS 33 nl')


plt.xlim(10,3000)
plt.ylim(5e-12,1e-7)
plt.ylabel('$C_L^{\kappa \kappa}$',fontsize=20)
plt.xlabel('L',fontsize=20)
plt.legend(loc='lower left',fontsize=14,ncol=1)
plotpath='/home/nessa/Documents/Projects/LensingBispectrum/CMB-nonlinear/Tests/GalaxyLensing/'
#plt.savefig(plotpath+'CLsJia_nu.png',bbox_inches='tight')
plt.show()

# %%
L,l,theta   = pickle.load(open(ellpath+'ell_ang_equilat_Lmin10_Lmax3000_lmin10_lmax8000_lenL200_lenl220_lenang200_0e+00.pkl','r'))
specpath='/home/nessa/Documents/Projects/LensingBispectrum/CMB-nonlinear/outputs/power_spectra/'
CL_11 = np.load(specpath+'CL_CLtest05_equilat_Takada_Lmin10-Lmax2999_halofit.npy')
ll1, cls11, cls11_ = np.load(specpath+'CL_CLtest05_equilat_Takada_Lmin10-Lmax2999_halofit_CLASS.npy')
plt.figure()
CL_22 = np.load(specpath+'CL_CLtest25_equilat_Takada_Lmin10-Lmax2999_halofit.npy')
ll, cls22, cls22_ = np.load(specpath+'CL_CLtest25_equilat_Takada_Lmin10-Lmax2999_halofit_CLASS.npy')
CL_12 = np.load(specpath+'CL_CLtestcross_equilat_Takada_Lmin10-Lmax2999_halofit.npy')
ll, cls12, cls12_ = np.load(specpath+'CL_CLtestcross_equilat_Takada_Lmin10-Lmax2999_halofit_CLASS.npy')
plt.figure()
plt.title('delta function source dis test' )
plt.loglog(L,CL_11,label='my code 11')
plt.loglog(L,CL_22,label='my code 22')
plt.loglog(L,CL_12,label='my code 12')
plt.loglog(ll1,cls11_,ls='--',label='CLASS 11')
plt.loglog(ll,cls22_,ls='--',label='CLASS 22')
plt.loglog(ll,cls12_,ls='--',label='CLASS 12')
plt.xlim(10,3000)
plt.ylim(5e-11,1e-7)
plt.ylabel('$C_L^{\kappa \kappa}$',fontsize=20)
plt.xlabel('L',fontsize=20)
plt.legend(loc='best',fontsize=14,ncol=2)
plotpath='/home/nessa/Documents/Projects/LensingBispectrum/CMB-nonlinear/Tests/GalaxyLensing/'
plt.savefig(plotpath+'CLsClassComp_nl.pdf',bbox_inches='tight')
plt.show()

# %%
plt.title('Difference between my code and CLASS in percent (nl)')
plt.plot(L,(CL_11/np.interp(L,ll1,cls11_)-1)*100,label='zs=0.5')
plt.plot(L,(CL_22/np.interp(L,ll,cls22_)-1)*100,label='zs=2.5')
plt.plot(L,(CL_12/np.interp(L,ll,cls12_)-1)*100,label='zs=2.5/0.5')
plt.xlim(100,3000)
plt.xlabel('L',fontsize=20)
plt.ylabel('$(C_L^{\mathrm{Code}}/C_L^{\mathrm{CLASS}}-1) [\%]$',fontsize=20)
plt.grid()
plt.legend(loc='best',fontsize=14)
plt.ylim(-0,3)
plt.savefig(plotpath+'CLsClassComp_nl_rel.png',bbox_inches='tight')

# %%
np.load(specpath+'CL_deltatest_equilat_Takada_Lmin10-Lmax2999_.npy')

# %%
#equilat including post born
#add L file
specpath='/home/nessa/Documents/Projects/LensingBispectrum/CMB-nonlinear/outputs/bispectra/'
L,l,theta = pickle.load(open(ellpath+'ell_ang_equilat_Lmin10_Lmax3000_lmin10_lmax8000_lenL200_lenl220_lenang200_0e+00.pkl','r'))
bi_equi = np.load(specpath+'bispec_333_massive_nus_equilat_JiaGalaxyLens_Lmin10-Lmax2999-lmax2999_halofit_SC.npy')
bi_equipB = np.load(specpath+'bispec_333_massive_nus_equilat_JiaGalaxyLens_Lmin10-Lmax2999-lmax2999_halofit_SC_post_born.npy')
bi_equisum = np.load(specpath+'bispec_333_massive_nus_equilat_JiaGalaxyLens_Lmin10-Lmax2999-lmax2999_halofit_SC_post_born_sum.npy')
bi_equinu = np.load(specpath+'bispec_333_equilat_JiaGalaxyLens_Lmin10-Lmax2999-lmax2999_halofit_SC.npy')
bi_equipBnu = np.load(specpath+'bispec_333_equilat_JiaGalaxyLens_Lmin10-Lmax2999-lmax2999_halofit_SC_post_born.npy')
bi_equisumnu = np.load(specpath+'bispec_333_equilat_JiaGalaxyLens_Lmin10-Lmax2999-lmax2999_halofit_SC_post_born_sum.npy')

bi_equi1 = np.load(specpath+'bispec_111_massive_nus_equilat_JiaGalaxyLens_Lmin10-Lmax2999-lmax2999_halofit_SC.npy')
bi_equipB1 = np.load(specpath+'bispec_111_massive_nus_equilat_JiaGalaxyLens_Lmin10-Lmax2999-lmax2999_halofit_SC_post_born.npy')
bi_equisum1 = np.load(specpath+'bispec_111_massive_nus_equilat_JiaGalaxyLens_Lmin10-Lmax2999-lmax2999_halofit_SC_post_born_sum.npy')
bi_equinu1 = np.load(specpath+'bispec_111_equilat_JiaGalaxyLens_Lmin10-Lmax2999-lmax2999_halofit_SC.npy')
bi_equipBnu1 = np.load(specpath+'bispec_111_equilat_JiaGalaxyLens_Lmin10-Lmax2999-lmax2999_halofit_SC_post_born.npy')
bi_equisumnu1 = np.load(specpath+'bispec_111_equilat_JiaGalaxyLens_Lmin10-Lmax2999-lmax2999_halofit_SC_post_born_sum.npy')


plt.figure()
plt.loglog(L, L**2*bi_equi,label='333 SC fit LSS')
plt.loglog(L, L**2*bi_equipB,label='333 SC fit post Born')
plt.loglog(L, L**2*bi_equinu,label='333 SC fit LSS mnu=0.1')
plt.loglog(L, L**2*bi_equipBnu,ls='--',label='333 SC fit post Born mnu=0.1')
plt.loglog(L, L**2*bi_equisum,ls='--',label='333 SC fit LSS+ post Born')
plt.loglog(L, L**2*bi_equisumnu,ls='--',label='333 SC fit LSS+ post Born mnu=0.1')

plt.loglog(L, L**2*bi_equi1,label='111 SC fit LSS')
plt.loglog(L, L**2*bi_equipB1,label='111 SC fit post Born')
plt.loglog(L, L**2*bi_equinu1,label='111 SC fit LSS mnu=0.1')
plt.loglog(L, L**2*bi_equipBnu1,ls='--',label='111 SC fit post Born mnu=0.1')
plt.loglog(L, L**2*bi_equisum1,ls='--',label='111 SC fit LSS+ post Born')
plt.loglog(L, L**2*bi_equisumnu1,ls='--',label='111 SC fit LSS+ post Born mnu=0.1')

plt.xlim(100,3000)
plt.legend(loc=(1.01,0.2))
plt.xlabel('L')
plt.ylabel('$L^2 b(L,L,L)$')
plotpath='/home/nessa/Documents/Projects/LensingBispectrum/CMB-nonlinear/Tests/GalaxyLensing/'
plt.savefig(plotpath+'bispec_equilat_postBorn.png',bbox_inches='tight')
plt.show()



plt.figure()
plt.semilogx(L, bi_equipB/bi_equisum,label='333 no massive neutrinos')
plt.semilogx(L, bi_equipBnu/bi_equisumnu,label='333 massive neutrinos')
plt.semilogx(L, bi_equipB1/bi_equisum1,label='111 no massive neutrinos')
plt.semilogx(L, bi_equipBnu1/bi_equisumnu1,label='111 massive neutrinos')
plt.xlim(100,3000)
plt.legend(loc='best')
plt.xlabel('L')
plt.ylabel('$b_{pB}(L,L,L)/b_{tot}(L,L,L)$')
plotpath='/home/nessa/Documents/Projects/LensingBispectrum/CMB-nonlinear/Tests/GalaxyLensing/'
plt.savefig(plotpath+'bispec_equilat_postBorn_ratio.png',bbox_inches='tight')
plt.show()

# %%
#squeezed including post born
specpath='/home/nessa/Documents/Projects/LensingBispectrum/CMB-nonlinear/outputs/bispectra/'
L,l,theta = pickle.load(open(ellpath+'ell_ang_squeezed_Lmin10_Lmax3000_lmin10_lmax8000_lenL200_lenl220_lenang200_1e-03.pkl','r'))
bi_equi = np.load(specpath+'bispec_333_squeezed_ang0.001_JiaGalaxyLens_Lmin10-Lmax2999-lmax2999_halofit_SC.npy')
bi_equipB = np.load(specpath+'bispec_333_squeezed_ang0.001_JiaGalaxyLens_Lmin10-Lmax2999-lmax2999_halofit_SC_post_born.npy')
bi_equisum = np.load(specpath+'bispec_333_squeezed_ang0.001_JiaGalaxyLens_Lmin10-Lmax2999-lmax2999_halofit_SC_post_born_sum.npy')




bi_equinu = np.load(specpath+'bispec_333_massive_nus_squeezed_ang0.001_JiaGalaxyLens_Lmin10-Lmax2999-lmax2999_halofit_SC.npy')
bi_equinupB = np.load(specpath+'bispec_333_massive_nus_squeezed_ang0.001_JiaGalaxyLens_Lmin10-Lmax2999-lmax2999_halofit_SC_post_born.npy')# bi_equir = np.load(specpath+'bispec_333retest_squeezed_ang0.001_JiaGalaxyLens_Lmin1-Lmax2999-lmax2999_halofit_SC.npy')
bi_equinusum = np.load(specpath+'bispec_333_massive_nus_squeezed_ang0.001_JiaGalaxyLens_Lmin10-Lmax2999-lmax2999_halofit_SC_post_born_sum.npy')# bi_equipBr = np.load(specpath+'bispec_333retest_squeezed_ang0.001_JiaGalaxyLens_Lmin1-Lmax2999-lmax2999_halofit_SC_post_born.npy')
# bi_equisumr = np.load(specpath+'bispec_333retest_squeezed_ang0.001_JiaGalaxyLens_Lmin1-Lmax2999-lmax2999_halofit_SC_post_born_sum.npy')

L_,l,theta = pickle.load(open(ellpath+'ell_ang_squeezed_Lmin1_Lmax3000_lmin1_lmax8000_lenL200_lenl220_lenang200_1e-03.pkl'))

# bi_equi1 = np.load(specpath+'bispec_111_retest_equilat_JiaGalaxyLens_Lmin10-Lmax10000-lmax10000_halofit_SC.npy')
# bi_equipB1 = np.load(specpath+'bispec_111_retest_equilat_JiaGalaxyLens_Lmin10-Lmax10000-lmax10000_halofit_SC_post_born.npy')
# bi_equisum1 = np.load(specpath+'bispec_111_retest_equilat_JiaGalaxyLens_Lmin10-Lmax10000-lmax10000_halofit_SC_post_born_sum.npy')
# bi_equipBnu = np.load(specpath+'bispec_333_massive_nus_equilat_JiaGalaxyLens_Lmin10-Lmax10000-lmax10000_halofit_SC_post_born.npy')


plt.figure()
plt.loglog(L, L**2*bi_equi,label='333 SC fit LSS')
plt.loglog(L, L**2*bi_equipB,label='333 SC fit post Born')
plt.loglog(L, L**2*bi_equisum,ls='--',label='333 SC fit LSS+ post Born')
# plt.loglog(L_, L_**2*bi_equir,ls='-.',label='333 SC fit LSS 2')
# plt.loglog(L_, L_**2*bi_equipBr,ls='-.',label='333 SC fit post Born 2')
# plt.loglog(L_, L_**2*bi_equisumr,ls='-.',label='333 SC fit LSS+ post Born 2')
plt.loglog(L, L**2*bi_equinu,label='111 SC fit LSS mnu=0.1')
plt.loglog(L, L**2*bi_equinupB,label='111 SC fit post Born mnu=0.1')
plt.loglog(L, L**2*bi_equinusum,ls='--',label='111 SC fit LSS+ post Born mnu=0.1')
plt.xlim(100,3000)
plt.legend(loc='best')
plt.xlabel('L')
plt.ylabel('$L^2 b(L,L,L)$')
plotpath='/home/nessa/Documents/Projects/LensingBispectrum/CMB-nonlinear/Tests/GalaxyLensing/'
plt.savefig(plotpath+'bispec_squeezed_postBorn.png',bbox_inches='tight')
plt.show()



plt.figure()
plt.semilogx(L, bi_equipB/bi_equisum,label='333 no massive neutrinos')
plt.semilogx(L, bi_equinupB/bi_equinusum,label='333 mnu=0.1', ls='--')
plt.xlim(100,3000)
plt.legend(loc='best')
plt.xlabel('L')
plt.ylabel('$b_{pB}(L,L,L)/b_{tot}(L,L,L)$')
plotpath='/home/nessa/Documents/Projects/LensingBispectrum/CMB-nonlinear/Tests/GalaxyLensing/'
plt.savefig(plotpath+'bispec_squeezed_postBorn_ratio.png',bbox_inches='tight')
plt.show()
