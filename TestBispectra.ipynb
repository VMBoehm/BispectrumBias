# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pickle
import numpy as np
plt.style.use(['seaborn-colorblind','paper'])
plt.style.use('classic')

# %%
ellpath="/home/nessa/Documents/Projects/LensingBispectrum/CMB-nonlinear/outputs/ells/"
specpath='/home/nessa/Documents/Projects/LensingBispectrum/CMB-nonlinear/outputs/bispectra/'

# %%
#folded
L,l,theta = pickle.load(open(ellpath+'ell_ang_folded_Lmin10_Lmax10000_lmin10_lmax8000_lenL200_lenl220_lenang200_0e+00.pkl','r'))
bi_fold_tl = np.load(specpath+'bispec_phi_test_folded_Pratten_Paper_Lmin10-Lmax10000-lmax5000-lenBi200_.npy')
bi_fold_fit = np.load(specpath+'bispec_phi_test_folded_Pratten_Paper_Lmin10-Lmax10000-lmax5000-lenBi200_SC.npy')

plt.figure()

plt.loglog(L, bi_fold_tl)
plt.loglog(L, bi_fold_fit)
plt.xlim(100,10000)
plt.ylim(1e-20,1e-13)
plt.show()

# %%
#equilat
L,l,theta = pickle.load(open(ellpath+'ell_ang_equilat_Lmin10_Lmax10000_lmin10_lmax8000_lenL200_lenl220_lenang200_0e+00.pkl','r'))
bi_equi_tl = np.load(specpath+'bispec_phi_test_equilat_Pratten_Paper_Lmin10-Lmax10000-lmax10000-lenBi200_.npy')
bi_equi_fit = np.load(specpath+'bispec_phi_test_equilat_Pratten_Paper_Lmin10-Lmax10000-lmax10000-lenBi200_SC.npy')

plt.figure()

plt.loglog(L, bi_equi_tl)
plt.loglog(L, bi_equi_fit)
plt.xlim(100,10000)
plt.ylim(1e-20,1e-13)
plt.show()

# %%
specpath='/home/nessa/Documents/Projects/LensingBispectrum/CMB-nonlinear/outputs/bispectra/'
L,l,theta = pickle.load(open(ellpath+'ell_ang_equilat_Lmin10_Lmax3000_lmin10_lmax8000_lenL200_lenl220_lenang200_0e+00.pkl','r'))
bi_equi_111 = np.load(specpath+'bispec_111_equilat_Takada_Lmin10-Lmax2999-lmax2999_halofit_SC.npy')
bi_equi_222 = np.load(specpath+'bispec_222_equilat_Takada_Lmin10-Lmax2999-lmax2999_halofit_SC.npy')
bi_equi_112 = np.load(specpath+'bispec_112_equilat_Takada_Lmin10-Lmax2999-lmax2999_halofit_SC.npy')
bi_equi_122 = np.load(specpath+'bispec_122_equilat_Takada_Lmin10-Lmax2999-lmax2999_halofit_SC.npy')
plt.figure()
plt.title('Fig. 3 in astro-ph/0310125v4' )
plt.loglog(L, L**4*bi_equi_111/(2*np.pi)**2,c='r',label='111')
plt.loglog(L, L**4*bi_equi_222/(2*np.pi)**2,c='b',label='222')
plt.loglog(L, L**4*bi_equi_112/(2*np.pi)**2,c='g',label='112')
plt.loglog(L, L**4*bi_equi_122/(2*np.pi)**2,c='orange',label='122')
plt.xlim(10,3000)
plt.ylim(5e-11,3e-5)
plt.legend(loc='best')
plt.xlabel('L')
plt.ylabel('$L^4 B(L,L,L)/(2\pi)^2$')
plotpath='/home/nessa/Documents/Projects/LensingBispectrum/CMB-nonlinear/Tests/GalaxyLensing/'
plt.savefig(plotpath+'bispec_equilat.pdf',bbox_inches='tight')
plt.show()

# %%
L,l,theta   = pickle.load(open(ellpath+'ell_ang_equilat_Lmin10_Lmax3000_lmin10_lmax8000_lenL200_lenl220_lenang200_0e+00.pkl','r'))
specpath='/home/nessa/Documents/Projects/LensingBispectrum/CMB-nonlinear/outputs/power_spectra/'
CL_11 = np.load(specpath+'CL_111_equilat_Takada_Lmin10-Lmax2999_halofit.npy')
CL_22 = np.load(specpath+'CL_222_equilat_Takada_Lmin10-Lmax2999_halofit.npy')
CL_12 = np.load(specpath+'CL_122_equilat_Takada_Lmin10-Lmax2999_halofit.npy')
plt.figure()
plt.title('Fig. 2 in astro-ph/0310125v4' )
plt.loglog(L, L*(L+1)*CL_11/(2*np.pi),c='r',label='11')
plt.loglog(L, L*(L+1)*CL_22/(2*np.pi),c='b',label='22')
plt.loglog(L, L*(L+1)*CL_12/(2*np.pi),c='g',label='12')
plt.xlim(10,3000)
plt.ylim(1e-6,1e-3)
plt.ylabel('$L(L+1) C_L^{\kappa \kappa}/(2\pi)$')
plt.xlabel('L')
plt.legend(loc='best')
plotpath='/home/nessa/Documents/Projects/LensingBispectrum/CMB-nonlinear/Tests/GalaxyLensing/'
plt.savefig(plotpath+'CLs.pdf',bbox_inches='tight')
plt.show()

# %%
specpath='/home/nessa/Documents/Projects/LensingBispectrum/CMB-nonlinear/outputs/bispectra/'
L,l,theta = pickle.load(open(ellpath+'ell_ang_equilat_Lmin10_Lmax3000_lmin10_lmax8000_lenL200_lenl220_lenang200_0e+00.pkl','r'))
bi_equi = np.load(specpath+'bispec_deltatest_equilat_Takada_Lmin10-Lmax2999-lmax2999_halofit_SC.npy')

plt.figure()
plt.title('delta function test')
plt.loglog(L, L*2*bi_equi,c='r',label='111')
plt.xlim(100,3000)
plt.legend(loc='best')
plt.xlabel('L')
plt.ylabel('$L^2 b(L,L,L)$')
plotpath='/home/nessa/Documents/Projects/LensingBispectrum/CMB-nonlinear/Tests/GalaxyLensing/'
#plt.savefig(plotpath+'bispec_equilat.pdf',bbox_inches='tight')
plt.show()

# %%
L,l,theta   = pickle.load(open(ellpath+'ell_ang_equilat_Lmin10_Lmax3000_lmin10_lmax8000_lenL200_lenl220_lenang200_0e+00.pkl','r'))
specpath='/home/nessa/Documents/Projects/LensingBispectrum/CMB-nonlinear/outputs/power_spectra/'
CL_11 = np.load(specpath+'CL_CLtest05_equilat_Takada_Lmin10-Lmax2999_halofit.npy')
ll1, cls11, cls11_ = np.load(specpath+'CL_CLtest05_equilat_Takada_Lmin10-Lmax2999_halofit_CLASS.npy')
plt.figure()
CL_22 = np.load(specpath+'CL_CLtest25_equilat_Takada_Lmin10-Lmax2999_halofit.npy')
ll, cls22, cls22_ = np.load(specpath+'CL_CLtest25_equilat_Takada_Lmin10-Lmax2999_halofit_CLASS.npy')
CL_12 = np.load(specpath+'CL_CLtestcross_equilat_Takada_Lmin10-Lmax2999_halofit.npy')
ll, cls12, cls12_ = np.load(specpath+'CL_CLtestcross_equilat_Takada_Lmin10-Lmax2999_halofit_CLASS.npy')
plt.figure()
plt.title('delta function test' )
plt.loglog(L,CL_11,label='my code 11')
plt.loglog(L,CL_22,label='my code 22')
plt.loglog(L,CL_12,label='my code 12')
plt.loglog(ll1,cls11_,ls='--',label='CLASS 11')
plt.loglog(ll,cls22_,ls='--',label='CLASS 22')
plt.loglog(ll,cls12_,ls='--',label='CLASS 12')
plt.xlim(10,3000)
plt.ylim(5e-12,1e-7)
plt.ylabel('$C_L^{\kappa \kappa}$',fontsize=20)
plt.xlabel('L',fontsize=20)
plt.legend(loc='best',fontsize=14,ncol=2)
plotpath='/home/nessa/Documents/Projects/LensingBispectrum/CMB-nonlinear/Tests/GalaxyLensing/'
plt.savefig(plotpath+'CLsClassComp_nl.pdf',bbox_inches='tight')
plt.show()

# %%
plt.title('Difference between my and CLASS in percent (nl)')
plt.plot(L,(CL_11/np.interp(L,ll1,cls11_)-1)*100,label='zs=0.5')
plt.plot(L,(CL_22/np.interp(L,ll,cls22_)-1)*100,label='zs=2.5')
plt.plot(L,(CL_12/np.interp(L,ll,cls12_)-1)*100,label='zs=2.5/0.5')
plt.xlim(100,3000)
plt.xlabel('L',fontsize=20)
plt.ylabel('$C_L^{\mathrm{Code}}/C_L^{\mathrm{CLASS}}-1$',fontsize=20)
plt.grid()
plt.legend(loc='best',fontsize=14)
plt.savefig(plotpath+'CLsClassComp_nl_rel.pdf',bbox_inches='tight')
plt.ylim(-0,3)
# Out:
# (0, 3)

# %%
np.load(specpath+'CL_deltatest_equilat_Takada_Lmin10-Lmax2999_.npy')
# Out:
# array([  2.21724891e-08,   2.19783193e-08,   2.17761699e-08,
#          2.15671117e-08,   2.13513725e-08,   2.11285066e-08,
#          2.08981305e-08,   2.06597104e-08,   2.04126927e-08,
#          2.01571782e-08,   1.98941799e-08,   1.96248695e-08,
#          1.93499906e-08,   1.90700772e-08,   1.87856549e-08,
#          1.84967955e-08,   1.82032669e-08,   1.79050305e-08,
#          1.76025073e-08,   1.72960770e-08,   1.69863824e-08,
#          1.66741203e-08,   1.63596932e-08,   1.60436213e-08,
#          1.57264795e-08,   1.54083577e-08,   1.50893700e-08,
#          1.47701760e-08,   1.44512165e-08,   1.41324926e-08,
#          1.38146808e-08,   1.34982874e-08,   1.31835978e-08,
#          1.28707331e-08,   1.25601251e-08,   1.22520891e-08,
#          1.19469343e-08,   1.16446853e-08,   1.13456276e-08,
#          1.10502224e-08,   1.07584842e-08,   1.04703353e-08,
#          1.01862651e-08,   9.90638098e-09,   9.63050319e-09,
#          9.35871032e-09,   9.09147612e-09,   8.82846575e-09,
#          8.56963159e-09,   8.31519954e-09,   8.06522037e-09,
#          7.81937786e-09,   7.57779809e-09,   7.34060726e-09,
#          7.10757512e-09,   6.87865656e-09,   6.65395274e-09,
#          6.43347016e-09,   6.21699412e-09,   6.00467049e-09,
#          5.79651598e-09,   5.59248175e-09,   5.39259510e-09,
#          5.19696039e-09,   5.00558415e-09,   4.81850648e-09,
#          4.63585119e-09,   4.45765789e-09,   4.28403045e-09,
